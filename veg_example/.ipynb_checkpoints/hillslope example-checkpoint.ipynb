# %%
# %matplotlib inline

# %%
if True: 
    import matplotlib.pylab as plt
    import numpy as np

# %%
def openfile(fname):
    f =  open(fname, 'r')

    line = f.next()
    a = (line.strip().split(" "))
    a = [b for b in a if b]

    Nx = int(a[0])
    Ny = int(a[1])
    Nz = int(a[2])

    Sx = float(a[3])
    Sy = float(a[4])
    Sz = float(a[5])

    Ox = float(a[6])
    Oy = float(a[7])
    Oz = float(a[8])

    line = f.next()
    a = (line.strip().split(" "))
    a = [b for b in a if b]
    nvar = int(a[0])

    line = f.next()
    a = (line.strip().split(" "))
    a = [b for b in a if b]
    name_of_variable_1 = (a[0])
    print name_of_variable_1
    
    facies = np.zeros([Nx, Ny])
    for i in range(Ny):
        for j in range(Nx):
            facies[i, j] = int(f.next().split()[0])
            
    return facies

# %%
test = openfile("ti.gslib")
test_real00000 = openfile("output/test_real00000.gslib")
# Out:
# veg
# veg_real00000

# %%
fig = plt.figure(figsize = (9,4))
ax = fig.add_subplot(121)
plt.imshow(test, cmap = 'Greens')
plt.title('Training image')
ax = fig.add_subplot(122)
plt.imshow(test_real00000, cmap = 'Greens')
plt.title('Simulation image')
fig.savefig('Success.pdf')

# %%
import os
os.chdir('output')
prefixed = [filename for filename in os.listdir('.') if filename.startswith("test")]

# %%
veg = []
for name in prefixed:
    veg.append(openfile(name))
# Out:
# veg_real00000
# veg_real00001
# veg_real00002
# veg_real00003

# %%
for i in range(len(veg)):
    fig = plt.figure(figsize = (9,4))
    ax = fig.add_subplot(121)
    plt.imshow(test, cmap = 'Greens')
    plt.title('Training image')
    ax = fig.add_subplot(122)
    plt.imshow(veg[i], cmap = 'Greens')
    plt.title('Simulation image')
    fig.savefig('../plots/veg{}.pdf'.format(i))
